# %%
import os

# %%
import cv2
import os




pathIn = 'scooby2.mp4'
pathOut = "object detection api/images"
name = ""
int_desiredLength=3
sec = 1.5


if not os.path.exists(pathOut):
    os.makedirs(pathOut)


if os.path.exists(pathIn):

    cap = cv2.VideoCapture(pathIn)
    fps = cap.get(cv2.CAP_PROP_FPS)
    fps = fps
    fps_2_capture = round(sec * fps)

    actual_frame = 0
    vid_frame_saved = 0

    while (cap.isOpened()):

        ret, frame = cap.read()

        #get current frame
        frameId = round(cap.get(1))



        if not ret == True:
            break

        if frameId % fps_2_capture == 0:

            vid_frame = 'frame' + str(actual_frame)
            #str_0 conv int to str
            fname = name + '_{str_0:0>{str_1}}.jpg'.format(str_0=vid_frame_saved, str_1=int_desiredLength)

            print('Extracting {} to: {}'.format(vid_frame , fname))
            cv2.imwrite(os.path.join(pathOut, fname), frame)

            vid_frame_saved += 1

    actual_frame += 1

else:
    print('path to video file does not exist')

print('Finished Extracting')

cap.release()
cv2.destroyAllWindows()
# Out:
# Extracting frame0 to: _000.jpg
# Extracting frame0 to: _001.jpg
# Extracting frame0 to: _002.jpg
# Extracting frame0 to: _003.jpg
# Extracting frame0 to: _004.jpg
# Extracting frame0 to: _005.jpg
# Extracting frame0 to: _006.jpg
# Extracting frame0 to: _007.jpg
# Extracting frame0 to: _008.jpg
# Extracting frame0 to: _009.jpg
# Extracting frame0 to: _010.jpg
# Extracting frame0 to: _011.jpg
# Extracting frame0 to: _012.jpg
# Extracting frame0 to: _013.jpg
# Extracting frame0 to: _014.jpg
# Extracting frame0 to: _015.jpg
# Extracting frame0 to: _016.jpg
# Extracting frame0 to: _017.jpg
# Extracting frame0 to: _018.jpg
# Extracting frame0 to: _019.jpg
# Extracting frame0 to: _020.jpg
# Extracting frame0 to: _021.jpg
# Extracting frame0 to: _022.jpg
# Extracting frame0 to: _023.jpg
# Extracting frame0 to: _024.jpg
# Extracting frame0 to: _025.jpg
# Extracting frame0 to: _026.jpg
# Extracting frame0 to: _027.jpg
# Extracting frame0 to: _028.jpg
# Extracting frame0 to: _029.jpg
# Extracting frame0 to: _030.jpg
# Extracting frame0 to: _031.jpg
# Extracting frame0 to: _032.jpg
# Extracting frame0 to: _033.jpg
# Extracting frame0 to: _034.jpg
# Extracting frame0 to: _035.jpg
# Extracting frame0 to: _036.jpg
# Extracting frame0 to: _037.jpg
# Extracting frame0 to: _038.jpg
# Extracting frame0 to: _039.jpg
# Extracting frame0 to: _040.jpg
# Extracting frame0 to: _041.jpg
# Extracting frame0 to: _042.jpg
# Extracting frame0 to: _043.jpg
# Extracting frame0 to: _044.jpg
# Extracting frame0 to: _045.jpg
# Extracting frame0 to: _046.jpg
# Extracting frame0 to: _047.jpg
# Extracting frame0 to: _048.jpg
# Extracting frame0 to: _049.jpg
# Extracting frame0 to: _050.jpg
# Extracting frame0 to: _051.jpg
# Extracting frame0 to: _052.jpg
# Extracting frame0 to: _053.jpg
# Extracting frame0 to: _054.jpg
# Extracting frame0 to: _055.jpg
# Extracting frame0 to: _056.jpg
# Extracting frame0 to: _057.jpg
# Extracting frame0 to: _058.jpg
# Extracting frame0 to: _059.jpg
# Extracting frame0 to: _060.jpg
# Extracting frame0 to: _061.jpg
# Extracting frame0 to: _062.jpg
# Extracting frame0 to: _063.jpg
# Extracting frame0 to: _064.jpg
# Extracting frame0 to: _065.jpg
# Extracting frame0 to: _066.jpg
# Extracting frame0 to: _067.jpg
# Extracting frame0 to: _068.jpg
# Extracting frame0 to: _069.jpg
# Extracting frame0 to: _070.jpg
# Extracting frame0 to: _071.jpg
# Extracting frame0 to: _072.jpg
# Extracting frame0 to: _073.jpg
# Extracting frame0 to: _074.jpg
# Extracting frame0 to: _075.jpg
# Extracting frame0 to: _076.jpg
# Extracting frame0 to: _077.jpg
# Extracting frame0 to: _078.jpg
# Extracting frame0 to: _079.jpg
# Extracting frame0 to: _080.jpg
# Extracting frame0 to: _081.jpg
# Extracting frame0 to: _082.jpg
# Extracting frame0 to: _083.jpg
# Extracting frame0 to: _084.jpg
# Extracting frame0 to: _085.jpg
# Extracting frame0 to: _086.jpg
# Extracting frame0 to: _087.jpg
# Extracting frame0 to: _088.jpg
# Extracting frame0 to: _089.jpg
# Extracting frame0 to: _090.jpg
# Extracting frame0 to: _091.jpg
# Extracting frame0 to: _092.jpg
# Extracting frame0 to: _093.jpg
# Extracting frame0 to: _094.jpg
# Extracting frame0 to: _095.jpg
# Extracting frame0 to: _096.jpg
# Extracting frame0 to: _097.jpg
# Extracting frame0 to: _098.jpg
# Extracting frame0 to: _099.jpg
# Extracting frame0 to: _100.jpg
# Extracting frame0 to: _101.jpg
# Extracting frame0 to: _102.jpg
# Extracting frame0 to: _103.jpg
# Extracting frame0 to: _104.jpg
# Extracting frame0 to: _105.jpg
# Extracting frame0 to: _106.jpg
# Extracting frame0 to: _107.jpg
# Extracting frame0 to: _108.jpg
# Extracting frame0 to: _109.jpg
# Extracting frame0 to: _110.jpg
# Extracting frame0 to: _111.jpg
# Extracting frame0 to: _112.jpg
# Extracting frame0 to: _113.jpg
# Extracting frame0 to: _114.jpg
# Extracting frame0 to: _115.jpg
# Extracting frame0 to: _116.jpg
# Extracting frame0 to: _117.jpg
# Extracting frame0 to: _118.jpg
# Extracting frame0 to: _119.jpg
# Extracting frame0 to: _120.jpg
# Extracting frame0 to: _121.jpg
# Extracting frame0 to: _122.jpg
# Extracting frame0 to: _123.jpg
# Extracting frame0 to: _124.jpg
# Extracting frame0 to: _125.jpg
# Extracting frame0 to: _126.jpg
# Extracting frame0 to: _127.jpg
# Extracting frame0 to: _128.jpg
# Extracting frame0 to: _129.jpg
# Extracting frame0 to: _130.jpg
# Extracting frame0 to: _131.jpg
# Extracting frame0 to: _132.jpg
# Extracting frame0 to: _133.jpg
# Extracting frame0 to: _134.jpg
# Extracting frame0 to: _135.jpg
# Extracting frame0 to: _136.jpg
# Extracting frame0 to: _137.jpg
# Extracting frame0 to: _138.jpg
# Extracting frame0 to: _139.jpg
# Extracting frame0 to: _140.jpg
# Extracting frame0 to: _141.jpg
# Extracting frame0 to: _142.jpg
# Extracting frame0 to: _143.jpg
# Extracting frame0 to: _144.jpg
# Extracting frame0 to: _145.jpg
# Extracting frame0 to: _146.jpg
# Extracting frame0 to: _147.jpg
# Extracting frame0 to: _148.jpg
# Extracting frame0 to: _149.jpg
# Extracting frame0 to: _150.jpg
# Extracting frame0 to: _151.jpg
# Extracting frame0 to: _152.jpg
# Extracting frame0 to: _153.jpg
# Extracting frame0 to: _154.jpg
# Extracting frame0 to: _155.jpg
# Extracting frame0 to: _156.jpg
# Extracting frame0 to: _157.jpg
# Extracting frame0 to: _158.jpg
# Extracting frame0 to: _159.jpg
# Extracting frame0 to: _160.jpg
# Extracting frame0 to: _161.jpg
# Extracting frame0 to: _162.jpg
# Finished Extracting

# %%
len(os.listdir('object detection api/images'))
# Out:
# 106

# %%
import os
import glob
import cv2

fnames = glob.glob(os.path.join("object detection api/images", "*.{}".format("jpg")))

# %%
fnames
# Out:
# ['object detection api/images\\_000.jpg',
#  'object detection api/images\\_001.jpg',
#  'object detection api/images\\_002.jpg',
#  'object detection api/images\\_003.jpg',
#  'object detection api/images\\_004.jpg',
#  'object detection api/images\\_005.jpg',
#  'object detection api/images\\_010.jpg',
#  'object detection api/images\\_013.jpg',
#  'object detection api/images\\_016.jpg',
#  'object detection api/images\\_021.jpg',
#  'object detection api/images\\_022.jpg',
#  'object detection api/images\\_027.jpg',
#  'object detection api/images\\_028.jpg',
#  'object detection api/images\\_029.jpg',
#  'object detection api/images\\_030.jpg',
#  'object detection api/images\\_031.jpg',
#  'object detection api/images\\_032.jpg',
#  'object detection api/images\\_034.jpg',
#  'object detection api/images\\_035.jpg',
#  'object detection api/images\\_037.jpg',
#  'object detection api/images\\_038.jpg',
#  'object detection api/images\\_043.jpg',
#  'object detection api/images\\_044.jpg',
#  'object detection api/images\\_045.jpg',
#  'object detection api/images\\_048.jpg',
#  'object detection api/images\\_051.jpg',
#  'object detection api/images\\_057.jpg',
#  'object detection api/images\\_058.jpg',
#  'object detection api/images\\_060.jpg',
#  'object detection api/images\\_061.jpg',
#  'object detection api/images\\_062.jpg',
#  'object detection api/images\\_066.jpg',
#  'object detection api/images\\_069.jpg',
#  'object detection api/images\\_070.jpg',
#  'object detection api/images\\_071.jpg',
#  'object detection api/images\\_072.jpg',
#  'object detection api/images\\_073.jpg',
#  'object detection api/images\\_074.jpg',
#  'object detection api/images\\_075.jpg',
#  'object detection api/images\\_076.jpg',
#  'object detection api/images\\_077.jpg',
#  'object detection api/images\\_078.jpg',
#  'object detection api/images\\_079.jpg',
#  'object detection api/images\\_080.jpg',
#  'object detection api/images\\_081.jpg',
#  'object detection api/images\\_082.jpg',
#  'object detection api/images\\_083.jpg',
#  'object detection api/images\\_084.jpg',
#  'object detection api/images\\_085.jpg',
#  'object detection api/images\\_086.jpg',
#  'object detection api/images\\_087.jpg',
#  'object detection api/images\\_088.jpg',
#  'object detection api/images\\_090.jpg',
#  'object detection api/images\\_091.jpg',
#  'object detection api/images\\_092.jpg',
#  'object detection api/images\\_093.jpg',
#  'object detection api/images\\_094.jpg',
#  'object detection api/images\\_097.jpg',
#  'object detection api/images\\_098.jpg',
#  'object detection api/images\\_099.jpg',
#  'object detection api/images\\_100.jpg',
#  'object detection api/images\\_101.jpg',
#  'object detection api/images\\_102.jpg',
#  'object detection api/images\\_103.jpg',
#  'object detection api/images\\_104.jpg',
#  'object detection api/images\\_105.jpg',
#  'object detection api/images\\_106.jpg',
#  'object detection api/images\\_107.jpg',
#  'object detection api/images\\_108.jpg',
#  'object detection api/images\\_109.jpg',
#  'object detection api/images\\_110.jpg',
#  'object detection api/images\\_111.jpg',
#  'object detection api/images\\_114.jpg',
#  'object detection api/images\\_115.jpg',
#  'object detection api/images\\_116.jpg',
#  'object detection api/images\\_117.jpg',
#  'object detection api/images\\_118.jpg',
#  'object detection api/images\\_119.jpg',
#  'object detection api/images\\_120.jpg',
#  'object detection api/images\\_121.jpg',
#  'object detection api/images\\_122.jpg',
#  'object detection api/images\\_123.jpg',
#  'object detection api/images\\_124.jpg',
#  'object detection api/images\\_125.jpg',
#  'object detection api/images\\_130.jpg',
#  'object detection api/images\\_132.jpg',
#  'object detection api/images\\_133.jpg',
#  'object detection api/images\\_134.jpg',
#  'object detection api/images\\_135.jpg',
#  'object detection api/images\\_137.jpg',
#  'object detection api/images\\_138.jpg',
#  'object detection api/images\\_139.jpg',
#  'object detection api/images\\_142.jpg',
#  'object detection api/images\\_143.jpg',
#  'object detection api/images\\_145.jpg',
#  'object detection api/images\\_147.jpg',
#  'object detection api/images\\_148.jpg',
#  'object detection api/images\\_153.jpg',
#  'object detection api/images\\_154.jpg',
#  'object detection api/images\\_155.jpg',
#  'object detection api/images\\_156.jpg',
#  'object detection api/images\\_158.jpg',
#  'object detection api/images\\_159.jpg',
#  'object detection api/images\\_160.jpg',
#  'object detection api/images\\_161.jpg',
#  'object detection api/images\\_162.jpg']

# %%
for i, fname in enumerate(fnames):
    print(".", end="", flush=True)
    img = cv2.imread(fname)	
    #print(fname)
    img_small = cv2.resize(img, (300,300))
    new_fname = fname.split("\\")[1]
    small_fname = os.path.join("object detection api/resized", new_fname)
    cv2.imwrite(small_fname, img_small)
    print("Done resizing {} files.\nSaved to directory: `{}`".format(len(fnames), "object detection api/resized"))
# Out:
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`
# .Done resizing 106 files.
# Saved to directory: `object detection api/resized`

# %%
for i in os.listdir('object detection api/images'):
    print(i)
# Out:
# _000.jpg
# _001.jpg
# _002.jpg
# _003.jpg
# _004.jpg
# _005.jpg
# _010.jpg
# _013.jpg
# _016.jpg
# _021.jpg
# _022.jpg
# _027.jpg
# _028.jpg
# _029.jpg
# _030.jpg
# _034.jpg
# _035.jpg
# _037.jpg
# _038.jpg
# _043.jpg
# _044.jpg
# _045.jpg
# _048.jpg
# _051.jpg
# _057.jpg
# _058.jpg
# _060.jpg
# _061.jpg
# _062.jpg
# _066.jpg
# _069.jpg
# _070.jpg
# _071.jpg
# _072.jpg
# _073.jpg
# _074.jpg
# _075.jpg
# _076.jpg
# _077.jpg
# _080.jpg
# _081.jpg
# _082.jpg
# _083.jpg
# _084.jpg
# _085.jpg
# _086.jpg
# _087.jpg
# _088.jpg
# _090.jpg
# _091.jpg
# _092.jpg
# _093.jpg
# _094.jpg
# _097.jpg
# _098.jpg
# _099.jpg
# _100.jpg
# _101.jpg
# _102.jpg
# _103.jpg
# _104.jpg
# _105.jpg
# _106.jpg
# _107.jpg
# _108.jpg
# _109.jpg
# _110.jpg
# _111.jpg
# _114.jpg
# _115.jpg
# _116.jpg
# _117.jpg
# _118.jpg
# _119.jpg
# _120.jpg
# _121.jpg
# _122.jpg
# _123.jpg
# _124.jpg
# _130.jpg
# _132.jpg
# _133.jpg
# _134.jpg
# _135.jpg
# _137.jpg
# _138.jpg
# _142.jpg
# _143.jpg
# _145.jpg
# _147.jpg
# _148.jpg
# _153.jpg
# _154.jpg
# _155.jpg
# _156.jpg
# _158.jpg
# _159.jpg
# _160.jpg
# _161.jpg
# _162.jpg
